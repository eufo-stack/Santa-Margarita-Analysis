# %% [markdown]
# # North Station 11, and New2_river_bottom_oak lowest

# %%
# imports
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

# %%
# inputs
file_name = '11011838_DEPO_incoming_run1_NS11.xlsx'
title = 'North Station 11'

# %% [markdown]
# New River 2 Bottom

# %%
# new river 2 bottom
import datetime
bot = pd.read_csv('./11011840_run4_Newriver2_bottom - 11011840_run4_Newriver2_bottom.csv.csv')
bot.dropna(subset = ['Unnamed: 2'], inplace=True)
bot = bot[:8259]
bot
# Out:
#      Plot Title: H8_run4            Unnamed: 1  \
# 0                      #  Date Time, GMT-07:00
# 1                      1   04/04/20 9:00:00 AM
# 2                      2  04/04/20 10:00:00 AM
# 3                      3  04/04/20 11:00:00 AM
# 4                      4  04/04/20 12:00:00 PM
# ...                  ...                   ...
# 8254                8254   03/14/21 6:00:00 AM
# 8255                8255   03/14/21 7:00:00 AM
# 8256                8256   03/14/21 8:00:00 AM
# 8257                8257   03/14/21 9:00:00 AM
# 8258                8258  03/14/21 10:00:00 AM
#
#                                            Unnamed: 2  \
# 0     Temp, °C (LGR S/N: 11011840, SEN S/N: 11011840)
# 1                                              18.461
# 2                                              15.843
# 3                                              14.768
# 4                                              16.654
# ...                                               ...
# 8254                                            7.242
# 8255                                            7.519
# 8256                                             8.07
# 8257                                           10.492
# 8258                                           11.321
#
#                                         Unnamed: 3  \
# 0     RH, % (LGR S/N: 11011840, SEN S/N: 11011840)
# 1                                            67.53
# 2                                           69.557
# 3                                           70.191
# 4                                           61.379
# ...                                            ...
# 8254                                        92.544
# 8255                                        93.071
# 8256                                        93.594
# 8257                                         83.93
# 8258                                        79.524
#
#                                 Unnamed: 4  \
# 0     Coupler Detached (LGR S/N: 11011840)
# 1                                   Logged
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 8254                                   NaN
# 8255                                   NaN
# 8256                                   NaN
# 8257                                   NaN
# 8258                                   NaN
#
#                                 Unnamed: 5  \
# 0     Coupler Attached (LGR S/N: 11011840)
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 8254                                   NaN
# 8255                                   NaN
# 8256                                   NaN
# 8257                                   NaN
# 8258                                   NaN
#
#                               Unnamed: 6                   Unnamed: 7  \
# 0     Host Connected (LGR S/N: 11011840)  Stopped (LGR S/N: 11011840)
# 1                                    NaN                          NaN
# 2                                    NaN                          NaN
# 3                                    NaN                          NaN
# 4                                    NaN                          NaN
# ...                                  ...                          ...
# 8254                                 NaN                          NaN
# 8255                                 NaN                          NaN
# 8256                                 NaN                          NaN
# 8257                                 NaN                          NaN
# 8258                                 NaN                          NaN
#
#                            Unnamed: 8
# 0     End Of File (LGR S/N: 11011840)
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 8254                              NaN
# 8255                              NaN
# 8256                              NaN
# 8257                              NaN
# 8258                              NaN
#
# [8259 rows x 9 columns]

# %%
# data cleaning
temp_all = list(map(float, bot.loc[:,'Unnamed: 2'][1:].values))

# %% [markdown]
# mon_arr = []
# for i in bot.loc[:,'Unnamed: 1'][1:].values:
#     mon = i[:2]
#     mon_arr.append(mon)

# %%
from datetime import datetime
for x in np.arange(len(bot['Unnamed: 1'])):
    if x == 0:
        continue
    datetime_object = datetime.strptime(bot['Unnamed: 1'][x], '%m/%d/%y %I:%M:%S %p')
    out_time = datetime.strftime(datetime_object, "%H:%M")
    bot['Unnamed: 1'][x] = datetime_object

# %%
# time series plot overall
y1 = temp_all
plt.plot(bot['Unnamed: 1'][1:], y1)


# plot styling
plt.title("New River 2 Bottom Oak Time Series (Lowest Elevation)")
plt.xlabel("Month")
plt.ylabel("Temp (C)")
plt.xticks(rotation=90)
plt.rcParams["figure.figsize"] = (20,3)
plt.ylim([-5, 50])

plt.show()
# Out:
# C:\Users\eudor\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# New 4 Lost Creek

# %%
import datetime
top = pd.read_excel(file_name)
top.dropna(subset = ['Unnamed: 2'], inplace=True)
start = datetime.datetime(2020, 4, 4, 8)
end = datetime.datetime(2021, 3, 14, 11)
top.drop(0,inplace=True)
top = top[top['Unnamed: 1'] > start]
top = top[top['Unnamed: 1'] < end]
top
# Out:
#      Plot Title: DEPO_incoming_run1           Unnamed: 1 Unnamed: 2  \
# 1718                           1718  2020-04-04 09:00:00     15.318
# 1719                           1719  2020-04-04 10:00:00     15.031
# 1720                           1720  2020-04-04 11:00:00     16.439
# 1721                           1721  2020-04-04 12:00:00     18.129
# 1722                           1722  2020-04-04 13:00:00     19.246
# ...                             ...                  ...        ...
# 9971                           9971  2021-03-14 06:00:00       7.72
# 9972                           9972  2021-03-14 07:00:00      8.519
# 9973                           9973  2021-03-14 08:00:00     11.151
# 9974                           9974  2021-03-14 09:00:00     11.346
# 9975                           9975  2021-03-14 10:00:00     12.292
#
#      Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 1718      69.17        NaN        NaN        NaN        NaN        NaN
# 1719     69.203        NaN        NaN        NaN        NaN        NaN
# 1720     63.753        NaN        NaN        NaN        NaN        NaN
# 1721     56.963        NaN        NaN        NaN        NaN        NaN
# 1722     56.184        NaN        NaN        NaN        NaN        NaN
# ...         ...        ...        ...        ...        ...        ...
# 9971     93.729        NaN        NaN        NaN        NaN        NaN
# 9972     92.418        NaN        NaN        NaN        NaN        NaN
# 9973     80.631        NaN        NaN        NaN        NaN        NaN
# 9974     77.939        NaN        NaN        NaN        NaN        NaN
# 9975     70.464        NaN        NaN        NaN        NaN        NaN
#
# [8258 rows x 9 columns]

# %%
# data cleaning
temp_all2 = list(map(float, top.loc[:,'Unnamed: 2'][1:].values))

# %% [markdown]
# for y in np.arange(len(top['Unnamed: 1'])):
#     if y == 0:
#         continue
#     datetime_object = datetime.strptime(top['Unnamed: 1'][y], '%m/%d/%y %I:%M:%S %p')
#     out_time = datetime.strftime(datetime_object, "%H:%M")
#     top['Unnamed: 1'][y] = datetime_object

# %%
# time series plot overall
y2 = temp_all2
plt.plot(top['Unnamed: 1'][1:], y2)


# plot styling
plt.title(title + " Time Series")
plt.xlabel("Month")
plt.ylabel("Temp (C)")
plt.xticks(rotation=90)
plt.rcParams["figure.figsize"] = (20,3)
plt.ylim([-5, 60])

plt.show()

# %% [markdown]
# Highest minus lowest elevation

# %% [markdown]
# # indexing out nans and matching lengths for subtraction
# top_ls = pd.to_numeric(top['Unnamed: 2']).to_numpy()
# bot_ls = pd.to_numeric(bot['Unnamed: 2'][1:]).to_numpy()
# print(len(top_ls),len(bot_ls))
# dif = top_ls - bot_ls
# print(len(dif))

# %% [markdown]
# # time series plot for difference between highest to lowest elevation
# y3 = dif
# print(len(top['Unnamed: 1']))
# plt.plot(top['Unnamed: 1'], y3)
#
#
# # plot styling
# plt.title("New 2 Lost Creek, New 2 River Bottom Difference Time Series")
# plt.xlabel("Month")
# plt.ylabel("Temp Difference (C)")
# plt.xticks(rotation=90)
# plt.rcParams["figure.figsize"] = (20,3)
# plt.ylim([-10, 10])
#
# plt.show()

# %% [markdown]
# Monthly Avg per Hr

# %%
# monthly avg per hr bot
def get_month_yr(datee):
    mon = datee.strftime('%m')
    yr = datee.year
    hr = datee.strftime('%H')
    return str(yr) + '-' + str(mon) + '-' + str(hr)
bot['yr-month-hr'] = bot['Unnamed: 1'][1:].apply(get_month_yr)

bot_cut = bot.iloc[1:8259].drop(['Unnamed: 3','Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6','Unnamed: 7', 'Unnamed: 8'],axis=1)    #keeping indexes the same
bot_cut
# Out:
#      Plot Title: H8_run4           Unnamed: 1 Unnamed: 2 yr-month-hr
# 1                      1  2020-04-04 09:00:00     18.461  2020-04-09
# 2                      2  2020-04-04 10:00:00     15.843  2020-04-10
# 3                      3  2020-04-04 11:00:00     14.768  2020-04-11
# 4                      4  2020-04-04 12:00:00     16.654  2020-04-12
# 5                      5  2020-04-04 13:00:00     18.033  2020-04-13
# ...                  ...                  ...        ...         ...
# 8254                8254  2021-03-14 06:00:00      7.242  2021-03-06
# 8255                8255  2021-03-14 07:00:00      7.519  2021-03-07
# 8256                8256  2021-03-14 08:00:00       8.07  2021-03-08
# 8257                8257  2021-03-14 09:00:00     10.492  2021-03-09
# 8258                8258  2021-03-14 10:00:00     11.321  2021-03-10
#
# [8258 rows x 4 columns]

# %%
# monthly avg
bot_cut['Unnamed: 2'] = bot_cut['Unnamed: 2'].apply(pd.to_numeric)
avgs = bot_cut.groupby('yr-month-hr')['Unnamed: 2'].mean().reset_index()
avgs
# Out:
#     yr-month-hr  Unnamed: 2
# 0    2020-04-00   12.317269
# 1    2020-04-01   12.337154
# 2    2020-04-02   12.288385
# 3    2020-04-03   12.124462
# 4    2020-04-04   11.658192
# ..          ...         ...
# 283  2021-03-19   11.880231
# 284  2021-03-20   10.259154
# 285  2021-03-21    9.379462
# 286  2021-03-22    8.860077
# 287  2021-03-23    8.291692
#
# [288 rows x 2 columns]

# %%
from datetime import datetime
lst = []
for a in np.arange(len(avgs['yr-month-hr'])):
    datetime_object = datetime.strptime(avgs['yr-month-hr'][a], '%Y-%m-%H')
    lst.append(datetime_object)
avgs['time'] = lst
avgs
# Out:
#     yr-month-hr  Unnamed: 2                time
# 0    2020-04-00   12.317269 2020-04-01 00:00:00
# 1    2020-04-01   12.337154 2020-04-01 01:00:00
# 2    2020-04-02   12.288385 2020-04-01 02:00:00
# 3    2020-04-03   12.124462 2020-04-01 03:00:00
# 4    2020-04-04   11.658192 2020-04-01 04:00:00
# ..          ...         ...                 ...
# 283  2021-03-19   11.880231 2021-03-01 19:00:00
# 284  2021-03-20   10.259154 2021-03-01 20:00:00
# 285  2021-03-21    9.379462 2021-03-01 21:00:00
# 286  2021-03-22    8.860077 2021-03-01 22:00:00
# 287  2021-03-23    8.291692 2021-03-01 23:00:00
#
# [288 rows x 3 columns]

# %%
#new bot
def get_hr(datee):
    hr = datee.strftime('%H')
    return str(hr)
avgs['hr'] = avgs['time'].apply(get_hr)
avgs
#
# Out:
#     yr-month-hr  Unnamed: 2                time  hr
# 0    2020-04-00   12.317269 2020-04-01 00:00:00  00
# 1    2020-04-01   12.337154 2020-04-01 01:00:00  01
# 2    2020-04-02   12.288385 2020-04-01 02:00:00  02
# 3    2020-04-03   12.124462 2020-04-01 03:00:00  03
# 4    2020-04-04   11.658192 2020-04-01 04:00:00  04
# ..          ...         ...                 ...  ..
# 283  2021-03-19   11.880231 2021-03-01 19:00:00  19
# 284  2021-03-20   10.259154 2021-03-01 20:00:00  20
# 285  2021-03-21    9.379462 2021-03-01 21:00:00  21
# 286  2021-03-22    8.860077 2021-03-01 22:00:00  22
# 287  2021-03-23    8.291692 2021-03-01 23:00:00  23
#
# [288 rows x 4 columns]

# %%
#new bot
high = avgs[avgs['hr'] == '14']
plt.plot(high['yr-month-hr'],high['Unnamed: 2'])
plt.xticks(rotation=90)
plt.title("New 4 River Bottom Monthly Avg Hr 14")
plt.xlabel("Year-Month-Hour")
plt.ylabel("Avg Temp (C)")
plt.ylim([0, 40])
plt.show()

low = avgs[avgs['hr'] == '06']
plt.plot(low['yr-month-hr'],low['Unnamed: 2'])
plt.xticks(rotation=90)
plt.title("New 4 River Bottom Monthly Avg Hr 6")
plt.xlabel("Year-Month-Hour")
plt.ylabel("Avg Temp (C)")
plt.ylim([0, 40])
plt.show()
#

# %% [markdown]
# plt.plot(avgs['yr-month-hr'],avgs['Unnamed: 2'])
# plt.xticks(rotation=90)
# plt.title("New 4 River Bottom Monthly Avg Per Hr")
# plt.xlabel("Year-Month-Hour")
# plt.ylabel("Avg Temp (C)")
# plt.show()

# %% [markdown]
# plt.plot(avgs['time'],avgs['Unnamed: 2'])
# plt.xticks(rotation=90)
# plt.title("New 4 River Bottom Difference Monthly Avg Per Hr")
# plt.xlabel("Year-Month-Hour")
# plt.ylabel("Avg Temp (C)")
# plt.show()

# %%
# monthly avg per hr top
def get_month_yr(datee):
    mon = datee.strftime('%m')
    yr = datee.year
    hr = datee.strftime('%H')
    return str(yr) + '-' + str(mon) + '-' + str(hr)
top['yr-month-hr'] = top['Unnamed: 1'][1:].apply(get_month_yr)

top_cut = top.iloc[1:8259].drop(['Unnamed: 3','Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6','Unnamed: 7'],axis=1)    #keeping indexes the same
# monthly avg
top_cut['Unnamed: 2'] = top_cut['Unnamed: 2'].apply(pd.to_numeric)
avgstop = top_cut.groupby('yr-month-hr')['Unnamed: 2'].mean().reset_index()

lsttop = []
for b in np.arange(len(avgstop['yr-month-hr'])):
    datetime_object = datetime.strptime(avgstop['yr-month-hr'][b], '%Y-%m-%H')
    lsttop.append(datetime_object)
avgstop['time'] = lsttop

def get_hr(datee):
    hr = datee.strftime('%H')
    return str(hr)
avgstop['hr'] = avgstop['time'].apply(get_hr)

hightop = avgstop[avgstop['hr'] == '14']
plt.plot(hightop['yr-month-hr'],hightop['Unnamed: 2'])
plt.xticks(rotation=90)
plt.title(title + " Monthly Avg Hr 14")
plt.xlabel("Year-Month-Hour")
plt.ylabel("Avg Temp (C)")
plt.ylim([0, 40])
plt.show()

lowtop = avgstop[avgstop['hr'] == '06']
plt.plot(lowtop['yr-month-hr'],lowtop['Unnamed: 2'])
plt.xticks(rotation=90)
plt.title(title + " Monthly Avg Hr 6")
plt.xlabel("Year-Month-Hour")
plt.ylabel("Avg Temp (C)")
plt.ylim([0, 40])
plt.show()

# %% [markdown]
# Difference

# %%
high_dif = (hightop['Unnamed: 2'] - high['Unnamed: 2']).to_numpy()
high['dif'] = high_dif
plt.plot(high['yr-month-hr'],high['dif'])
plt.xticks(rotation=90)
plt.title(title + ", New River 2 Bottom Monthly Avg Hr 14 Difference")
plt.xlabel("Year-Month-Hour")
plt.ylabel("Avg Temp (C)")
plt.ylim([-10, 10])
plt.show()
# Out:
# C:\Users\eudor\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
low_dif = (lowtop['Unnamed: 2'] - low['Unnamed: 2']).to_numpy()
low['dif'] = low_dif
plt.plot(low['yr-month-hr'],low['dif'])
plt.xticks(rotation=90)
plt.title(title + ", New River 2 Bottom Monthly Avg Hr 6 Difference")
plt.xlabel("Year-Month-Hour")
plt.ylabel("Avg Temp (C)")
plt.ylim([-10, 10])
plt.show()
# Out:
# C:\Users\eudor\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
